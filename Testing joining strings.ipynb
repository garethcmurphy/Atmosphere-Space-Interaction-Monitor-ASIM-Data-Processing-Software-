# %%
import pickle

path="/Users/garmu/Dropbox/asdc/web/"
temp_file_storage= pickle.load( open( path+"save.p", "rb" ) )

# %%
print sorted(temp_file_storage.keys())
# Out:
# ['0000_a0_init', '0000_a1_0000', '0000_a1_0001', '0000_a1_0002', '0000_a1_0003', '0000_a1_0004', '0000_a1_0005', '0000_a1_0006', '0000_a1_0007', '0000_a1_0008', '0000_a1_0009', '0000_a1_000a', '0000_a1_000b']

# %%
a=[''.join(value) for key, value in temp_file_storage.items() ]


b=a[0]
print b[-3:]
b=a[1]
print b[-3:]
b=a[2]
print b[-3:]
# Out:
# 30a
# 70a
# 00a

# %%
print (temp_file_storage['0000_a0_init'])
# Out:
# ...

# %%
mydict={'a0':'awk', 'a2':'aat', 'a1':'bat'}
qq=['-'.join(value) for key, value in mydict.items() if 'a' in key][0]
''.join([''.join(value) for key, value in sorted(mydict.items()) if 'a' in key])
# Out:
# 'awkbataat'

# %%
import textwrap

# %%
print a
# Out:
# ['...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...']

# %%
dl = textwrap.wrap(a[0], 4)

# %%
print(dl)
# Out:
# ['07e0', '018d', '019f', 'db87', '0000', '0106', '0000', '0114', '0000', '40ce', '000f', '4248', '0000', '0000', '0000', '0000', '045e', '044c', '0448', '0c25', '0000', '0000', '0000', '0000', '0000', '0000', '0000', '0000', '00c8', '0384', '00c8', '03ff', '0010', '03ff', '0010', '03ff', '0101', '0505', '1080', '012c', '03e8', '0bb8', '61a8', '012c', '03e8', '0bb8', '61a8', 'ffff', 'ff03', 'ffff', 'ffff', '03ff', '0000', '2e07', '5a40', '40ce', '0000', '0000', '0000', '0000', '0000', '08a8', '0000', '9805', '0560', '298d', '0000', '29a5', '9380', '2eda', '0000', '981a', '0170', '3071', '0000', '9019', '03f0', '30a4', '0000', '24ad', '3e40', '3897', '0000', '26c6', '6800', '3911', '0000', '9819', '0190', '39c0', '0000', '2318', '6a00', '3ec6', '0000', '9010', '0640', '465b', '0000', '9410', '0430', '4bde', '0000', '2529', '6d40', '4cf8', '0000', '2c3d', '8040', '539c', '0000', '248f', '9880', '5562', '0000', '2c39', '9880', '5575', '0000', '2106', '4cc0', '5a35', '0000', '29cc', '3980
# ...
