# %%
#!/usr/bin/env python

"""MXGSAuroralCaptureObservation_test_data_read_into_db-class-based.py: read raw data in database"""


__author__ 		= "Gareth Murphy"
__copyright__ 	= "Copyright 2016, ASDC, DTU Space"
__credits__ 	= ["spacepy, bitstring, textwrap, numpy"]
__license__ 	= "XXX"
__version__ 	= "0.0.1"
__maintainer__ 	= "Gareth Murphy"
__email__ 		= "gmurphy@space.dtu.dk"
__status__ 		= "Working version, finds and reads data correctly "

import os, sys


home="/Users/garmu/Dropbox/"
proj_path = home+"/asdc/web/python_template_site"

proj_path = home+"/myenv/mysite/"
# This is so Django knows where to find stuff.
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "mysite.settings")
sys.path.append(proj_path)

# This is so my local_settings.py gets loaded.
os.chdir(proj_path)

# This is so models get loaded.
from django.core.wsgi import get_wsgi_application
application = get_wsgi_application()


from asim.models import * 
    
print "Test 1"
# Out:
# Test 1

# %%
mylist=['37'  ]

import numpy as np

for tag in mylist:

    fname='PFM_20160513_0912_raw.txt'

    path='/Users/garmu/MXGS_PFM_data/PFM_20160513_0912/Section_5_3/raw/'


    #fname='PFM_20160513_0912_raw.txt'
    i=0

    import re


    MXGS = '80'
    GROUND = '92'
    SCIENCE_DATA = '02'
    INITIAL_TGF_TM ='a0'
    CONTINU_TGF_TM ='a1'
    INITIAL_BACKGR_TM ='a2'
    CONTINU_BACKGR_TM ='a3'
    INITIAL_PULSE_TM ='a4'
    CONTINU_PULSE_TM ='a5'
    INITIAL_SAMP_TM ='a6'
    CONTINU_SAMP_TM ='a7'
    INITIAL_AUR_TM ='a8'
    CONTINU_AUR_TM ='a9'

    regex = re.compile(MXGS+GROUND+SCIENCE_DATA+'a[89]....00'+tag)



    datalist=[]

    masterdata=[]
    total=0
    import textwrap

    with open (path+fname) as f:    
        for line in f:
            if re.match(regex,line):
                datalist.append(line)
                a=datalist[i]
                dl=textwrap.wrap(a, 4)

                from bitstring import Bits

                #f = open('file'+str(i).zfill(5)+'.ccsds', 'wb')
                #Bits('0x'+line).tofile(f)
                #f.close()
                
                if ( np.mod(i,100) == 0):
                    print 'file number ', i

                total =  total + hex2int (a[8:12])
                if ( i > 0) :
                # delete first 14 bytes/28 hex (Continuation Header)
                    dl=dl[8:]
                i=i+1
                masterdata.extend(dl)


    
    
print "Test 2"
# Out:
# file number  0
# file number  100
# file number  200
# file number  300
# file number  400
# file number  500
# file number  600
# file number  700
# file number  800
# file number  900
# file number  1000
# file number  1100
# file number  1200
# file number  1300
# file number  1400
# file number  1500
# file number  1600
# file number  1700
# file number  1800
# file number  1900
# file number  2000
# file number  2100
# file number  2200
# file number  2300
# file number  2400
# file number  2500
# file number  2600
# file number  2700
# file number  2800
# file number  2900
# file number  3000
# file number  3100
# file number  3200
# file number  3300
# file number  3400
# file number  3500
# file number  3600
# file number  3700
# file number  3800
# file number  3900
# file number  4000
# file number  4100
# file number  4200
# Test 2

# %%
x=MXGSAuroralCaptureObservation()
x.hexstring_to_db(masterdata)
print x.observation_id
x.save()




import pprint
stuff = x.__dict__
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(stuff)
# Out:
# 55
# {   '_state': <django.db.models.base.ModelState object at 0x114cec5d0>,
#     'auroral_capture_dur': 600,
#     'auroral_capture_thresh': 2000,
#     'end_dau_bgo_1_int_tmon_chan1': 1132,
#     'end_dau_bgo_1_int_tmon_chan2': 1117,
#     'end_dau_bgo_1_int_tmon_chan3': 1117,
#     'end_dau_bgo_1_int_tmon_chan4': 3120,
#     'end_dau_bgo_2_int_tmon_chan1': 1129,
#     'end_dau_bgo_2_int_tmon_chan2': 1114,
#     'end_dau_bgo_2_int_tmon_chan3': 1112,
#     'end_dau_bgo_2_int_tmon_chan4': 3116,
#     'end_dau_bgo_3_int_tmon_chan1': 1138,
#     'end_dau_bgo_3_int_tmon_chan2': 1124,
#     'end_dau_bgo_3_int_tmon_chan3': 1122,
#     'end_dau_bgo_3_int_tmon_chan4': 3135,
#     'end_dau_bgo_4_int_tmon_chan1': 1129,
#     'end_dau_bgo_4_int_tmon_chan2': 1112,
#     'end_dau_bgo_4_int_tmon_chan3': 1112,
#     'end_dau_bgo_4_int_tmon_chan4': 3117,
#     'hed_bin0_lr_boundary': 0,
#     'hed_bin1_lr_boundary': 25,
#     'hed_bin2_lr_boundary': 50,
#     'hed_bin3_lr_boundary': 75,
#     'hed_bin4_lr_boundary': 100,
#     'hed_bin5_lr_boundary': 125,
#     'hed_bin6_lr_boundary': 150,
#     'hed_bin7_lr_boundary': 175,
#     'hed_bin8_lr_boundary': 200,
#     'hed_bin9_lr_boundary': 225,
#     'hed_bin9_upr_boundary': 255,
#     'hed_bin_vals': <FieldFile: auroral_capture00000001.cdf>,
#     'hed_binned_vals': 2500,
#     'hed_temporal_bin_size': 50,
#     'id': 2,
#     'led_bin0_lr_boundary': 0,
#     'led_bin1_lr_boundary': 25,
#     'led_bin2_lr_boundary': 50,
#     'led_bin3_lr_boundary': 75,
#     'led_bin4_lr_boundary': 100,
#     'led_bin5_lr_boundary': 125,
#     'led_bin6_lr_boundary': 150,
#     'led_bin7_lr_boundary': 175,
#     'led_bin8_lr_boundary': 200,
#     'led_bin9_lr_boundary': 225,
#     'led_bin9_upr_boundary': 255,
#     'led_bin_vals': <FieldFile: auroral_capture00000001.cdf>,
#     'led_binned_vals': 2500,
#     'led_temporal_bin_size': 50,
#     'observation_id': 55,
#     'start_dau_bgo_1_int_tmon_chan1': 1130,
#     'start_dau_bgo_1_int_tmon_chan2': 1114,
#     'start_dau_bgo_1_int_tmon_chan3': 1115,
#     'start_dau_bgo_1_int_tmon_chan4': 3121,
#     'start_dau_bgo_2_int_tmon_chan1': 1126,
#     'start_dau_bgo_2_int_tmon_chan2': 1112,
#     'start_dau_bgo_2_int_tmon_chan3': 1110,
#     'start_dau_bgo_2_int_tmon_chan4': 3116,
#     'start_dau_bgo_3_int_tmon_chan1': 1136,
#     'start_dau_bgo_3_int_tmon_chan2': 1121,
#     'start_dau_bgo_3_int_tmon_chan3': 1120,
#     'start_dau_bgo_3_int_tmon_chan4': 3134,
#     'start_dau_bgo_4_int_tmon_chan1': 1127,
#     'start_dau_bgo_4_int_tmon_chan2': 1110,
#     'start_dau_bgo_4_int_tmon_chan3': 1110,
#     'start_dau_bgo_4_int_tmon_chan4': 3117,
#     'tcp_count_dhpu': 1948,
#     'tcp_count_dpu': 1945,
#     'utc_msec': 0,
#     'utc_seconds': 1948,
#     'utc_year': 1970}
