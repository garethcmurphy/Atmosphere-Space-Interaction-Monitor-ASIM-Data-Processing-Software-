# %%
infile = open('/Users/garmu/Desktop/ASIM_2101_full/test.txt', 'r')

per_row = []
for line in infile:
    per_row.append(line.strip())
    
    
print per_row[0:10]
# Out:
# ['80800120', '80800111', '80800123', '80800120', '80800111', '80800120', '80800111', '80800120', '80800111', '80800120']

# %%
from collections import Counter
myDict=Counter(per_row)

print myDict
# Out:
# Counter({'80800111': 13053, '0111004d': 13053, '80800120': 12854, '0120003a': 12854, '808001a1': 7775, '80800123': 3210, '01230033': 3210, '01a102d3': 2965, '808001a3': 2351, '80800125': 1282, '01250029': 1282, '012a0027': 1281, '8080012a': 1281, '01a102d1': 1040, '808001a0': 957, '808001a7': 827, '01a102cf': 744, '808001a5': 642, '01a102cd': 518, '01a502d3': 486, '01a102cb': 358, '01a302b9': 322, '01a302b7': 284, '01a302bb': 263, '01a002cf': 207, '808001a6': 198, '808001a2': 198, '01a302b5': 195, '01a102c9': 195, '01a102c7': 189, '01a002cd': 179, '01a302bd': 175, '01a302c9': 169, '01a102c5': 157, '01a102c3': 154, '01a002d1': 153, '01a002d3': 152, '01a302cb': 146, '01a002cb': 129, '01a102c1': 120, '01a302b3': 115, '01a302cd': 100, '01a302bf': 91, '01a702c5': 86, '80800410': 82, '01a102bf': 82, '04100002': 82, '01a702c3': 82, '01a302c7': 77, '01a702c9': 70, '01a102bd': 67, '01a702c1': 59, '01a702cb': 58, '01a302b1': 56, '01a702c7': 55, '01a702bf': 54, '01a102bb': 52, '808001a4': 48, '
# ...

# %%
open packet and read top 
buffer={}
if ( init_packet ):
    buffer['obsid'+str(packnum) ]=data
if (lastpacket):
    if (we_have_all_packets):
        call_parser
