# %%
#!/usr/bin/env python

"""MXGSSampledDetectorCounts_test_data_read_into_db-class-based-latest.py: read raw data in database"""


__author__ 		= "Gareth Murphy"
__copyright__ 	= "Copyright 2016, ASDC, DTU Space"
__credits__ 	= ["spacepy, bitstring, textwrap, numpy"]
__license__ 	= "XXX"
__version__ 	= "0.0.1"
__maintainer__ 	= "Gareth Murphy"
__email__ 		= "gmurphy@space.dtu.dk"
__status__ 		= "Working version, finds and reads data correctly "

import os, sys


home="/Users/garmu/Dropbox/"
proj_path = home+"/asdc/web/"

proj_path = home+"/myenv/mysite/"
# This is so Django knows where to find stuff.
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "mysite.settings")
sys.path.append(proj_path)

# This is so my local_settings.py gets loaded.
os.chdir(proj_path)

# This is so models get loaded.
from django.core.wsgi import get_wsgi_application
application = get_wsgi_application()


from asim.models import *

# %%
mylist=['06' ,'08' ,'0a' ,'0d' ,'0f' ,'12' ,'16' ,'19' ,'1c' ,'1f' ,'21' ,'25' ,'28' ,'2b' ,'2d' ,'30' ,'34']
mylist=['06']
mylist=['06' ,'08' ,'0a' ,'0d' ,'0f' ,'16' ,'19' ,'1c' ,'1f' ,'21' ,'25' ,'28' ,'2b' ,'2d' ,'30']


fname='PFM_20160513_0912_raw.txt'

path='/Users/garmu/MXGS_PFM_data/PFM_20160513_0912/Section_5_3/raw/'
    
mylist=['07' ,'09' ,'0b' ,'0e' ,'11' ,'15' ,'17' ,'1a' ,'1d' ,'20' ,'23' ,'26' ,'29' ,'2c' ,'2e' ,'32' ,'36']

    
for tag in mylist:




    #fname='PFM_20160513_0912_raw.txt'
    i=0

    import re


    MXGS = '80'
    GROUND = '92'
    SCIENCE_DATA = '02'
    INITIAL_TGF_TM ='a0'
    CONTINU_TGF_TM ='a1'
    INITIAL_BACKGR_TM ='a2'
    CONTINU_BACKGR_TM ='a3'
    INITIAL_PULSE_TM ='a4'
    CONTINU_PULSE_TM ='a5'
    INITIAL_SAMP_TM ='a6'
    CONTINU_SAMP_TM ='a7'
    INITIAL_AUR_TM ='a8'
    CONTINU_AUR_TM ='a9'

    regex = re.compile(MXGS+GROUND+SCIENCE_DATA+'a[67]....00'+tag)



    datalist=[]

    masterdata=[]
    total=0
    import textwrap

    with open (path+fname) as f:    
        for line in f:
            if re.match(regex,line):
                datalist.append(line)
                a=datalist[i]
                dl=textwrap.wrap(a, 4)

                from bitstring import Bits

                f = open('file'+str(i).zfill(3)+'.ccsds', 'wb')
                Bits('0x'+line).tofile(f)
                f.close()


                total =  total + hex2int (a[8:12])
                if ( i > 0) :
                    #print (dl[0:7])
                # delete first 14 bytes/28 hex (Continuation Header)
                # delete first 16 bytes/ 32 hex/ 8 groups of 4 hex characters
                    dl=dl[8:]
                i=i+1
                masterdata.extend(dl)

    
                
    x=MXGSSampledDetectorCounts()
    samp_det_counts=x.hexstring_to_db(masterdata)
    print x.observation_id
    x.save()
    qq=samp_det_counts
    for i in range(1,60):
    
        y=MXGSSampledDetectorCounts1Second()
        qq=y.hexstring_to_db(x,qq)
        y.save()
        #pp.pprint(stuff)
# Out:
# 0007
# 0009
# 000b
# 000e
# 0011
# 0015
# 0017
# 001a
# 001d
# 0020
# 0023
# 0026
# 0029
# 002c
# 002e
# 0032
# 0036

# %%
import pprint
stuff = x.__dict__
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(stuff)


stuff = y.__dict__
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(stuff)
# Out:
# {   '_state': <django.db.models.base.ModelState object at 0x1125a5dd0>,
#     'dau_bgo_1_int_tmon_chan1': 1130,
#     'dau_bgo_1_int_tmon_chan2': 1115,
#     'dau_bgo_1_int_tmon_chan3': 1115,
#     'dau_bgo_1_int_tmon_chan4': 3121,
#     'dau_bgo_2_int_tmon_chan1': 1126,
#     'dau_bgo_2_int_tmon_chan2': 1112,
#     'dau_bgo_2_int_tmon_chan3': 1109,
#     'dau_bgo_2_int_tmon_chan4': 3116,
#     'dau_bgo_3_int_tmon_chan1': 1136,
#     'dau_bgo_3_int_tmon_chan2': 1121,
#     'dau_bgo_3_int_tmon_chan3': 1120,
#     'dau_bgo_3_int_tmon_chan4': 3134,
#     'dau_bgo_4_int_tmon_chan1': 1127,
#     'dau_bgo_4_int_tmon_chan2': 1109,
#     'dau_bgo_4_int_tmon_chan3': 1110,
#     'dau_bgo_4_int_tmon_chan4': 3117,
#     'header': '809202a6',
#     'id': 57,
#     'observation_id': '0036'}
# {   '_mxgs_sampled_detector_counts_cache': <MXGSSampledDetectorCounts: MXGSSampledDetectorCounts object>,
#     '_state': <django.db.models.base.ModelState object at 0x112779710>,
#     'detector_counts': 3331,
#     'detector_events': <FieldFile: None>,
#     'dpu_count_prereset': 4044,
#     'dpu_count_sample_ratio': 1,
#     'grey_mode_data_reduc_factor': 14,
#     'id': 2006,
#     'mxgs_sampled_detector_counts_id': 57,
#     'tcp_count_dhpu': 4490,
#     'tcp_count_dpu': 843593714,
#     'utc_msec': 47108,
#     'utc_seconds': 55029161,
#     'utc_year': 0}
